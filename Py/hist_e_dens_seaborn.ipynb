# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/trees.csv')
df.head()

# %%
srn.distplot(df.Volume, bins = 10, axlabel = 'Volume').set_title('Árvores')

# %%
df_2 = pd.read_csv('data/chicken.csv')
df_2.head()

# %%
agrup = df_2.groupby(['feed'])['weight'].sum()
agrup

# %%
teste = df_2.loc[df_2['feed'] == 'horsebean']
teste

# %%
srn.distplot(df_2.loc[df_2['feed'] == 'horsebean'].weight, hist=False).set_title('horsebean')

# %%
srn.distplot(df_2.loc[df_2['feed'] == 'casein'].weight).set_title('casein')

# %%
srn.distplot(df_2.loc[df_2['feed'] == 'linseed'].weight).set_title('linseed')

# %%
srn.distplot(df_2.loc[df_2['feed'] == 'meatmeal'].weight).set_title('meatmeal')

# %%
srn.distplot(df_2.loc[df_2['feed'] == 'soybean'].weight).set_title('soybean')

# %%
srn.distplot(df_2.loc[df_2['feed'] == 'sunflower'].weight).set_title('sunflower')

# %%
#Graficos 2x3
plt.figure()
plt.subplot(3,2,1)
srn.distplot(df_2.loc[df_2['feed'] == 'horsebean'].weight, hist=False).set_title('horsebean')
plt.subplot(3,2,2)
srn.distplot(df_2.loc[df_2['feed'] == 'casein'].weight).set_title('casein')
plt.subplot(3,2,3)
srn.distplot(df_2.loc[df_2['feed'] == 'linseed'].weight).set_title('linseed')
plt.subplot(3,2,4)
srn.distplot(df_2.loc[df_2['feed'] == 'meatmeal'].weight).set_title('meatmeal')
plt.subplot(3,2,5)
srn.distplot(df_2.loc[df_2['feed'] == 'soybean'].weight).set_title('soybean')
plt.subplot(3,2,6)
srn.distplot(df_2.loc[df_2['feed'] == 'sunflower'].weight).set_title('sunflower')

#Ajustando layout para não ocorrer sobreposição
plt.tight_layout()
# Out:
# /var/folders/5d/zxdz5v6n6l5g_gp4cdn8dcy00000gn/T/ipykernel_40684/3011913194.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(df_2.loc[df_2['feed'] == 'horsebean'].weight, hist=False).set_title('horsebean')
# /var/folders/5d/zxdz5v6n6l5g_gp4cdn8dcy00000gn/T/ipykernel_40684/3011913194.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...
